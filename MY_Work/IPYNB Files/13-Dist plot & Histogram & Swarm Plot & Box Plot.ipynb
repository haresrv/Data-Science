# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
num = np.random.normal(1,10,1000)
sns.distplot(num)
# plt.show()

# %%
sns.distplot(num,kde=False)
#kernel density estimation

# %%
df = pd.read_csv("housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.hist(bins=40,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f099fcbb750>,
# ...
#       dtype=object)

# %%
sns.distplot(df['median_income'])

# %%
sns.distplot(df['median_income'],bins=20)

# %%
sns.distplot(df['median_income'],rug=True)

# %%
sns.distplot(df['median_income'],hist_kws=dict(edgecolor='#ffffff',linewidth=2),color='#222000')

# %%
sns.set(style='white')

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
fig,axes = plt.subplots(nrows=3,ncols=3,figsize=(20,20))
cols=['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']
k = 0
l = 0
for i in cols:
    sns.distplot(df[i],ax = axes[k,l],color='#00bcd4',bins=20)
    l+=1
    if l==3:
        k+=1
        l=0
    if k==3:
        break

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.swarmplot(x=df.smoker,y=df.charges)

# %%
sns.scatterplot(x=df.smoker,y=df.charges)

# %%
sns.swarmplot(y=df.smoker,x=df.charges)

# %%
iris = sns.load_dataset('iris')
sns.swarmplot(x="species",y="petal_width",data=iris,size=6)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig , axes = plt.subplots(nrows=2,ncols=2,figsize=(20,20))
sns.swarmplot(ax=axes[0,0],x="species",y="petal_width",data=iris,size=6)
sns.swarmplot(ax=axes[0,1],x="species",y="sepal_width",data=iris,size=6)
sns.swarmplot(ax=axes[1,0],x="species",y="sepal_length",data=iris,size=6)
sns.swarmplot(ax=axes[1,1],x="species",y="petal_length",data=iris,size=6)

# %%
sns.swarmplot(x="species",y="petal_width",data=iris,size=6,linewidth=2,edgecolor='black')

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.swarmplot(x=df.smoker,y=df.charges,hue=df.sex)

# %%
sns.catplot(x="smoker",y="charges",col="sex",data=df,kind='swarm',height=8,aspect=1)

# %%
sns.violinplot(x="species",y="petal_width",data=iris)

# %%
sns.violinplot(x="species",y="petal_width",data=iris,inner='quartile')

# %%
sns.violinplot(x="species",y="petal_width",data=iris,inner=None)

# %%
sns.boxplot(df.bmi)

# %%
sns.boxplot(x = df.smoker , y = df.charges)

# %%
sns.boxplot(x = df.smoker , y = df.charges,order=['no','yes'])

# %%
sns.boxplot(x = df.smoker , y = df.charges,hue=df.sex)

# %%
sns.boxplot(x = df.smoker , y = df.charges,hue=df.sex,width=0.1)

# %%
sns.boxplot(x = df.smoker , y = df.charges,hue=df.sex,width=0.1,palette={'female':'#ff0000','male':'#00ff00'})

# %%
sns.boxplot(x = df.smoker , y = df.charges,hue=df.sex,width=0.1)
sns.despine()

# %%
sns.boxplot(x = df.smoker , y = df.charges,hue=df.sex,width=0.8,linewidth=5)

# %%
sns.boxplot(y = df.smoker , x = df.charges,hue=df.sex,width=0.8,linewidth=5)
plt.xticks(rotation=45)
# Out:
# (array([-10000.,      0.,  10000.,  20000.,  30000.,  40000.,  50000.,
#          60000.,  70000.]),
#  <a list of 9 Text xticklabel objects>)

# %%
fig , axes = plt.subplots(nrows=2,ncols=2,figsize=(20,20))
sns.swarmplot(ax=axes[0,0],x="species",y="petal_width",data=iris,size=6)
sns.boxplot(ax=axes[0,1],x="species",y="petal_width",data=iris)
# sns.stripplot(ax=axes[1,0],x="species",y="sepal_length",data=iris,size=6)
# sns.swarmplot(ax=axes[1,1],x="species",y="petal_length",data=iris,size=6)

# %%
sns.stripplot(x="species",y="petal_width",data=iris,size=6)
sns.violinplot(x="species",y="petal_width",data=iris,size=6)

# %%
sns.swarmplot(x="species",y="petal_width",data=iris,size=6)
sns.boxplot(x="species",y="petal_width",data=iris)

# %%
sns.boxplot(x="species",y="petal_width",data=iris,boxprops={'facecolor':'None'})
sns.swarmplot(x="species",y="petal_width",data=iris,size=6)

# %%
sns.pairplot(iris,hue='species')

# %%
sns.pairplot(iris,hue='species',vars=['sepal_length','sepal_width'],aspect=1)
