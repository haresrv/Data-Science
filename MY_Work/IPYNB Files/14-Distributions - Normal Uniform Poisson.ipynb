# %%
import matplotlib.pyplot as plt
from IPython.display import Math,Latex
from IPython.core.display import Image

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

# %%
from scipy.stats import bernoulli
da= bernoulli.rvs(size=10000,p=0.6)

# %%
ax=sns.distplot(da , bins=100, kde=True, color='blue',hist_kws={"linewidth":15,"alpha":1})

# %%
from scipy.stats import weibull_min

# %%
import numpy as np

# %%
kv =[0.5,1,2,2]
lam=[1,1,1,2]
line =['-','--',':','-.','--']
mu=0
x=np.linspace(-10,10,1000)

# %%
fig,ax = plt.subplots(figsize=(5,3.75))

for (k,la,ls) in zip(kv,lam,line):
    dist = weibull_min(k,mu,la)
    plt.plot(x,dist.pdf(x),ls=ls,c='black',label=r'$k=%.1f,\ \lambda=%i$' % (k,la))
    
plt.xlim(0,5)
plt.ylim(0,1)

plt.xlabel('$x$')
plt.xlabel(r'$p(x|k,\lambda)$')
plt.title("Weibull")
plt.legend()
plt.show()

# %%
from scipy.stats import uniform

# %%
n=10000
st = 10
width = 20
data_uniform = uniform.rvs(size=n,loc=st,scale=width)

# %%
ax=sns.distplot(data_uniform , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()

# %%
from scipy.stats import norm

data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
ax = sns.distplot(data_normal,
                         bins=100,
                         kde=True,
                         color='skyblue',
                         hist_kws={"linewidth":15, "alpha":1})
ax.set(xlabel="Normal DIst",ylabel="Freq")
plt.show()

# %%
from scipy.stats import expon
data_expon = expon.rvs(size=1000,loc=0,scale=1)

# %%
ax = sns.distplot(data_expon,
                         bins=100,
                         kde=True,
                         color='green',
                         hist_kws={"linewidth":15, "alpha":1})
ax.set(xlabel="Normal DIst",ylabel="Freq")
plt.show()

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(size=1000,mu=3)

# %%
ax = sns.distplot(data_poisson,
                         bins=100,
                         kde=True,
                         color='green',
                         hist_kws={"linewidth":15, "alpha":1})
ax.set(xlabel="Normal DIst",ylabel="Freq")
plt.show()

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=1000)

# %%
ax = sns.distplot(data_binom,
                         bins=100,
                         kde=True,
                         color='green',
                         hist_kws={"linewidth":15, "alpha":1})
ax.set(xlabel="Normal DIst",ylabel="Freq")
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("distributions.csv")
df.head()
# Out:
#        col1      col2      col3  col4  col5
# 0  0.949179  0.928570  1.251634     2     1
# 1  0.347413  0.421874  0.031035     5     2
# 2 -0.254612  0.449669  0.124791     5     1
# 3 -1.345921  0.687092  1.444043     6     0
# 4 -1.392610  0.371138  0.067156     8     2

# %%
ax=sns.distplot(df['col1'] , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()

# %%
ax=sns.distplot(df['col2'] , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()

# %%
ax=sns.distplot(df['col3'] , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()

# %%
ax=sns.distplot(df['col4'] , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()

# %%
ax=sns.distplot(df['col5'] , bins=100, kde=True, color='skyblue',hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Uniform Distribution',ylabel='Frequency')
plt.show()
