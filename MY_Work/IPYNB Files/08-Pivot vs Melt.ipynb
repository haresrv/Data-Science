# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("http://files.zillowstatic.com/research/public_v2/invt_fs/Metro_invt_fs_uc_sfrcondo_smoothed_month.csv")
df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2017-10-31  2017-11-30  2017-12-31  2018-01-31  2018-02-28  ...  \
# 0       NaN   1660657.0   1600667.0   1526619.0   1491269.0   1429228.0  ...
# 1        NY     82960.0     79438.0     75253.0     73101.0     71028.0  ...
# 2        CA     25402.0     23886.0     22022.0     21475.0     20597.0  ...
# 3        IL     47461.0     44752.0     41690.0     40113.0     37662.0  ...
# 4        TX     29470.0     28086.0     26489.0     25581.0     24078.0  ...
#
#    2019-09-30  2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# ...

# %%
df2 = pd.read_csv("weather.csv")
df2
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
pd.melt(df2 , id_vars = ["day"])
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
melted = pd.melt(df2 , id_vars = ["day"],var_name="city",value_name="temperature")

# %%
unmelted = melted.pivot(index='day',columns='city')

# %%
unmelted.columns = melted.pivot(index='day',columns='city').columns.droplevel()

# %%
unmelted
# Out:
# city       berlin  chennai  chicago
# day
# Friday         30       83       30
# Monday         41       75       32
# Saturday       45       81       20
# Sunday         47       77       25
# Thursday       38       82       22
# Tuesday        43       77       30
# Wednesday      45       75       28

# %%
unmelted.reset_index()
# Out:
# city        day  berlin  chennai  chicago
# 0        Friday      30       83       30
# 1        Monday      41       75       32
# 2      Saturday      45       81       20
# 3        Sunday      47       77       25
# 4      Thursday      38       82       22
# 5       Tuesday      43       77       30
# 6     Wednesday      45       75       28

# %%
df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2017-10-31  2017-11-30  2017-12-31  2018-01-31  2018-02-28  ...  \
# 0       NaN   1660657.0   1600667.0   1526619.0   1491269.0   1429228.0  ...
# 1        NY     82960.0     79438.0     75253.0     73101.0     71028.0  ...
# 2        CA     25402.0     23886.0     22022.0     21475.0     20597.0  ...
# 3        IL     47461.0     44752.0     41690.0     40113.0     37662.0  ...
# 4        TX     29470.0     28086.0     26489.0     25581.0     24078.0  ...
#
#    2019-09-30  2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# ...

# %%
melted = pd.melt(df,var_name='year_value',value_name="count",id_vars=['RegionID','SizeRank','RegionName','RegionType','StateName'])                  
melted
# Out:
#       RegionID  SizeRank                          RegionName RegionType  \
# 0       102001         0                       United States    Country
# 1       394913         1                        New York, NY        Msa
# 2       753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3       394463         3                         Chicago, IL        Msa
# 4       394514         4               Dallas-Fort Worth, TX        Msa
# ...        ...       ...                                 ...        ...
# 3988    394586       504                       Faribault, MN        Msa
# 3989    394309       527                       Albemarle, NC        Msa
# 3990    394742       595                       Kerrville, TX        Msa
# 3991    395091       641                     Shelbyville, TN        Msa
# 3992    395230       672                      Wilmington, OH        Msa
#
#      StateName  year_value      count
# 0          NaN  2017-10-31  1660657.0
# ...

# %%
melted[melted["RegionName"]=='United States']
# Out:
#       RegionID  SizeRank     RegionName RegionType StateName  year_value  \
# 0       102001         0  United States    Country       NaN  2017-10-31
# 121     102001         0  United States    Country       NaN  2017-11-30
# 242     102001         0  United States    Country       NaN  2017-12-31
# 363     102001         0  United States    Country       NaN  2018-01-31
# 484     102001         0  United States    Country       NaN  2018-02-28
# 605     102001         0  United States    Country       NaN  2018-03-31
# 726     102001         0  United States    Country       NaN  2018-04-30
# 847     102001         0  United States    Country       NaN  2018-05-31
# 968     102001         0  United States    Country       NaN  2018-06-30
# 1089    102001         0  United States    Country       NaN  2018-07-31
# 1210    102001         0  United States    Country       NaN  2018-08-31
# 1331    102001         0  United States    Country       NaN  2018-09-30
# ...

# %%
melted[['year','month','date']] = melted['year_value'].str.split('-',expand=True)

# %%
melted
# Out:
#       RegionID  SizeRank                          RegionName RegionType  \
# 0       102001         0                       United States    Country
# 1       394913         1                        New York, NY        Msa
# 2       753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3       394463         3                         Chicago, IL        Msa
# 4       394514         4               Dallas-Fort Worth, TX        Msa
# ...        ...       ...                                 ...        ...
# 3988    394586       504                       Faribault, MN        Msa
# 3989    394309       527                       Albemarle, NC        Msa
# 3990    394742       595                       Kerrville, TX        Msa
# 3991    395091       641                     Shelbyville, TN        Msa
# 3992    395230       672                      Wilmington, OH        Msa
#
#      StateName  year_value      count  year month date
# ...

# %%
melted.drop(['year_value'],axis=1,inplace=True)
