# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pokemon_updated.csv",index_col=0)
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# #
# 1       65     45           1      False    318
# 2       80     60           1      False    405
# 3      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=df['Type 1'],y=df['Speed'],hue=df['Legendary'])

# %%
plt.style.use('seaborn-darkgrid')

# %%
x1 = np.array([250,150,350,252,450,550,455,358,158,355])
y1 = np.array([40,50,80,90,100,50,60,88,54,45])


x2 = np.array([200,100,300,220,400,500,450,380,180,350])
y2 = np.array([400,500,800,900,1000,500,600,808,504,405])

# plt.scatter(x1,y1)
# plt.xlabel('Time Spent',fontsize=12)
# plt.xlabel('Score',fontsize=12)
# plt.title('Scatter Graph')


# plt.scatter(x2,y2,color='r')
# plt.xlabel('Time Spent',fontsize=12)
# plt.xlabel('Score',fontsize=12)
# plt.title('Scatter Graph')

plt.scatter(x1,y1,label='Class 1')
plt.scatter(x2,y2,label='Class 2',color='r')
plt.xlabel('Time Spent',fontsize=12)
plt.xlabel('Score',fontsize=12)
plt.title('Scatter Graph')
plt.legend()

# %%
plt.scatter(x1,y1,marker='o',label='Class 1')
plt.scatter(x2,y2,marker='v',label='Class 2',color='r')
plt.xlabel('Time Spent',fontsize=12)
plt.xlabel('Score',fontsize=12)
plt.title('Scatter Graph')
plt.legend()

# %%
plt.figure(figsize=(10,6))
x = np.random.normal(0,10,1000)
y = np.random.normal(0,10,1000)
plt.scatter(x,y)

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=df.bmi,y=df.charges)

# %%
sns.scatterplot(x=df.bmi,y=df.charges,color='#91bd3a')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=df.bmi,y=df.charges,marker='v')

# %%
sns.scatterplot(x=df.bmi,y=df.charges,hue=df.sex)

# %%
sns.scatterplot(x=df.bmi,y=df.charges,hue=df.sex,style=df.smoker)
